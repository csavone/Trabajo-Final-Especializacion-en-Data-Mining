# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('/content/df_2012_preproc_sm_1min.xlsx', index_col="timestamp")
df2 = pd.read_excel('/content/df_2014_preproc_sm_1min.xlsx', index_col="timestamp")
df3 = pd.read_excel('/content/df_2015_preproc_sm_1min.xlsx', index_col="timestamp")

# %%
df_train = pd.concat([df1, df2], axis = 0)
df_test = df3

# %%
# Datos con variables y target numericas
X_train = df_train.drop(columns=['class'])
y_train= df_train['class']
X_test = df_test.drop(columns=['class'])
y_test= df_test['class']

# %%
#Escalado
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, make_scorer
from sklearn.model_selection import cross_val_score, StratifiedKFold

# %% [markdown]
# KNN - EXPERIMENTO BASE

# %%
#metric default : Minkowski Distance con p=2 (coincide con Euclidean)
import time

#Datos
X = X_train_sc
y = y_train

k_values = [i for i in range (3,40,4)]
scores = []

def custom_score(y_true, y_pred):
  NN, NT, NF, TN, TT, TF, FN, FT, FF = confusion_matrix(y_true, y_pred, labels=["Normal", "Transitorio", "Falla"] ).ravel()
  c_score = 15 * TT -2*NT-2*FT #high is good
  return c_score

scorer = make_scorer(custom_score, greater_is_better=True)

j = 1
for k in k_values:
  iteration_start_time = time.time()
  knn = KNeighborsClassifier(n_neighbors=k)
  #skf = StratifiedKFold(n_splits=5, shuffle=False)
  score = cross_val_score(knn, X, y, cv = 5, scoring = scorer, verbose = 8)
  scores.append(np.mean(score))
  iteration_end_time = time.time()
  duration = iteration_end_time - iteration_start_time
  print(f"Iteration {j} K = {k} duration: {duration:.4f} seconds\n")
  j = j+1

import matplotlib.pyplot as plt
plt.style.use("ggplot")

plt.plot(k_values, scores, marker='o', color='blue')
plt.xlabel("K-n_neighbors")
plt.ylabel("Ganancia")
plt.title("KNN_base")
plt.grid(True)
plt.show()
#Notar que el score obtenido es calculado sobre el fold del cross validation, por defecto cv es 5 así que está calculando la ganancia sobre el 20% de los datos
# Out:
# [CV] END ........................... score: (test=104886.000) total time=   0.3s
# [CV] END ........................... score: (test=110910.000) total time=   0.4s
# [CV] END ........................... score: (test=113400.000) total time=   0.8s
# [CV] END ........................... score: (test=113105.000) total time=   0.9s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    2.5s
# [CV] END ............................ score: (test=82546.000) total time=   0.6s
# Iteration 1 K = 3 duration: 3.0692 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.0s finished
# [CV] END ........................... score: (test=105606.000) total time=   0.5s
# [CV] END ........................... score: (test=111150.000) total time=   0.5s
# [CV] END ........................... score: (test=113400.000) total time=   0.6s
# [CV] END ........................... score: (test=113105.000) total time=   0.6s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    2.2s
# [CV] END ............................ score: (test=89988.000) total time=   0.4s
# Iteration 2 K = 7 duration: 2.6662 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.6s finished
# [CV] END ........................... score: (test=107142.000) total time=   0.4s
# [CV] END ........................... score: (test=111195.000) total time=   0.5s
# [CV] END ........................... score: (test=113400.000) total time=   0.6s
# [CV] END ........................... score: (test=113105.000) total time=   0.6s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    2.2s
# [CV] END ........................... score: (test=105412.000) total time=   0.4s
# Iteration 3 K = 11 duration: 2.6283 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.6s finished
# [CV] END ........................... score: (test=107189.000) total time=   0.4s
# [CV] END ........................... score: (test=111195.000) total time=   0.5s
# [CV] END ........................... score: (test=113400.000) total time=   0.6s
# [CV] END ........................... score: (test=113105.000) total time=   0.6s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    2.3s
# [CV] END ........................... score: (test=105620.000) total time=   0.5s
# Iteration 4 K = 15 duration: 2.7739 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.7s finished
# [CV] END ........................... score: (test=107851.000) total time=   0.4s
# [CV] END ........................... score: (test=111210.000) total time=   0.6s
# [CV] END ........................... score: (test=113400.000) total time=   0.7s
# [CV] END ........................... score: (test=113105.000) total time=   0.7s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    2.4s
# [CV] END ........................... score: (test=105822.000) total time=   0.8s
# Iteration 5 K = 19 duration: 3.2261 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.2s finished
# [CV] END ........................... score: (test=108365.000) total time=   0.8s
# [CV] END ........................... score: (test=111210.000) total time=   1.0s
# [CV] END ........................... score: (test=113400.000) total time=   0.7s
# [CV] END ........................... score: (test=113105.000) total time=   0.7s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    3.2s
# [CV] END ........................... score: (test=112988.000) total time=   0.5s
# Iteration 6 K = 23 duration: 3.8481 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.8s finished
# [CV] END ........................... score: (test=109254.000) total time=   0.5s
# [CV] END ........................... score: (test=111225.000) total time=   0.6s
# [CV] END ........................... score: (test=113400.000) total time=   0.7s
# [CV] END ........................... score: (test=113105.000) total time=   0.7s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    2.6s
# [CV] END ........................... score: (test=113246.000) total time=   0.6s
# Iteration 7 K = 27 duration: 3.1549 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.1s finished
# [CV] END ........................... score: (test=111716.000) total time=   0.5s
# [CV] END ........................... score: (test=111195.000) total time=   0.7s
# [CV] END ........................... score: (test=113400.000) total time=   0.7s
# [CV] END ........................... score: (test=113105.000) total time=   0.8s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    2.7s
# [CV] END ........................... score: (test=113246.000) total time=   0.6s
# Iteration 8 K = 31 duration: 3.2908 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.3s finished
# [CV] END ........................... score: (test=112575.000) total time=   0.5s
# [CV] END ........................... score: (test=111180.000) total time=   0.7s
# [CV] END ........................... score: (test=113400.000) total time=   1.0s
# [CV] END ........................... score: (test=113105.000) total time=   1.2s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    3.5s
# [CV] END ........................... score: (test=113242.000) total time=   0.9s
# Iteration 9 K = 35 duration: 4.4640 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.4s finished
# [CV] END ........................... score: (test=112532.000) total time=   0.5s
# [CV] END ........................... score: (test=111150.000) total time=   0.7s
# [CV] END ........................... score: (test=113400.000) total time=   0.8s
# [CV] END ........................... score: (test=113105.000) total time=   0.8s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    2.9s
# [CV] END ........................... score: (test=113236.000) total time=   0.6s
# Iteration 10 K = 39 duration: 3.5390 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.5s finished

# %%
# Create a k-NN classifier with x neighbors
KNN = KNeighborsClassifier(n_neighbors=35)

X_train = X_train_sc
y_train = y_train
X_test = X_test_sc
y_test = y_test

KNN.fit(X_train,y_train)

y_pred_train = KNN.predict(X_train)
y_pred_test = KNN.predict(X_test)

# %%
#Métricas en train

y_true = y_train
y_pred = y_pred_train

def custom_score(y_true, y_pred):
  NN, NT, NF, TN, TT, TF, FN, FT, FF = confusion_matrix(y_true, y_pred, labels=["Normal", "Transitorio", "Falla"] ).ravel()

  gan = 15*TT -2*NT-2*FT #high is good

  F1_T = (2*TT) / (2*TT + NT + FT + TN + TF) # F1-score p transitorio
  Acc = (NN+TT+FF)/(NN+NT+NF+TN+TT+TF+FN+FT+FF) # Accuracy global

  FPR = (NT+FT) / (NN+NT+NF+FN+FT+FF) # False Positive Rate

  Prec_T = TT / (NT + TT + FT) #Precision

  Recall_T = TT / (TN + TT + TF) #Recall

  return gan, F1_T, Acc, FPR, Prec_T, Recall_T

gan, F1_T, Acc, FPR, Prec_T, Recall_T = custom_score(y_true, y_pred)
print("Ganancia: ", gan)
print("F1_score_transitorio: ", round(F1_T,5))
print("Accuracy: ", round(Acc,5))
print("FPR: ", round(FPR,5))
print("Precision: ", round(Prec_T,5))
print("Recall: ", round(Recall_T,5))
# Out:
# Ganancia:  566333
# F1_score_transitorio:  0.99876
# Accuracy:  0.99829
# FPR:  0.00325
# Precision:  0.99852
# Recall:  0.99899

# %%
#Métricas en test
y_true = y_test
y_pred = y_pred_test

def custom_score(y_true, y_pred):
  NN, NT, NF, TN, TT, TF, FN, FT, FF = confusion_matrix(y_true, y_pred, labels=["Normal", "Transitorio", "Falla"] ).ravel()

  gan = 15*TT -2*NT-2*FT #high is good

  F1_T = (2*TT) / (2*TT + NT + FT + TN + TF) # F1-score p transitorio
  Acc = (NN+TT+FF)/(NN+NT+NF+TN+TT+TF+FN+FT+FF) # Accuracy global

  FPR = (NT+FT) / (NN+NT+NF+FN+FT+FF) # False Positive Rate

  Prec_T = TT / (NT + TT + FT) #Precision

  Recall_T = TT / (TN + TT + TF) #Recall

  return gan, F1_T, Acc, FPR, Prec_T, Recall_T

gan, F1_T, Acc, FPR, Prec_T, Recall_T = custom_score(y_true, y_pred)
print("Ganancia: ", gan)
print("F1_score_transitorio: ", round(F1_T,5))
print("Accuracy: ", round(Acc,5))
print("FPR: ", round(FPR,5))
print("Precision: ", round(Prec_T,5))
print("Recall: ", round(Recall_T,5))
# Out:
# Ganancia:  158004
# F1_score_transitorio:  0.97305
# Accuracy:  0.96433
# FPR:  0.0363
# Precision:  0.9816
# Recall:  0.96465

# %%
#timeline in true test
plt.rcParams.update(plt.rcParamsDefault)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import dates as mdates # Import mdates for date formatting

# Map categorical labels to numerical values
y_test_series = pd.Series(y_test, index=y_test.index)
y_num = y_test_series.map({'Normal': 0, 'Transitorio': 1, 'Falla': 2})

# Identify where the class changes
class_changes = y_num[y_num.diff() != 0]

# Create segments
segments = []
if not class_changes.empty:
    # First segment starts at the beginning of the series
    segments.append({'start': y_num.index[0], 'end': class_changes.index[0], 'class': y_num.iloc[0]})

    # Intermediate segments
    for i in range(len(class_changes) - 1):
        segments.append({
            'start': class_changes.index[i],
            'end': class_changes.index[i+1],
            'class': class_changes.iloc[i]
        })

    # Last segment starts at the last change point and ends at the end of the series
    segments.append({'start': class_changes.index[-1], 'end': y_num.index[-1], 'class': class_changes.iloc[-1]})
else:
    # If no class changes, the whole series is one segment
    if not y_num.empty:
        segments.append({'start': y_num.index[0], 'end': y_num.index[-1], 'class': y_num.iloc[0]})


fig, ax = plt.subplots(figsize=(12, 2)) # Adjust figure size as needed

# Define y-axis positions and colors for each class
y_positions = {0: 0, 1: 1, 2: 2}
class_colors = {0: 'green', 1: 'orange', 2: 'blue'} # Define colors for clarity
class_labels = {0: 'Normal', 1: 'Transitorio', 2: 'Falla'} # Define labels for legend

# Plot horizontal lines for each segment
for segment in segments:
    start_time = segment['start']
    end_time = segment['end']
    class_value = segment['class']
    y_pos = y_positions[class_value]
    color = class_colors[class_value]
    label = class_labels[class_value]

    # Plot a horizontal line for the segment
    ax.hlines(y_pos, start_time, end_time, color=color, lw=10) #lw line widht


first_transitorio_test = y_test[y_test == 'Transitorio'].index[0]
first_falla_test = y_test[y_test == 'Falla'].index[0]
ax.axvline(x=first_transitorio_test, color='red', linestyle='--', linewidth=1, label = 'Primer Transitorio real')

ax.axvline(x=first_falla_test, color='red', linestyle='dotted', linewidth=1, label = 'Primera Falla real')
ax.xaxis.set_major_locator(plt.MaxNLocator(5))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m %H:%M'))
#ax.set_xticklabels(ticklabels, fontsize=8);

#ax.set_ylabel("Class")
ax.set_title("Clase real")

# Set y-axis ticks and labels
ax.set_yticks([y_positions[0], y_positions[1], y_positions[2]])
ax.set_yticklabels(["Normal", "Transitorio", "Falla"])
ax.set_ylim(-0.5,2.5)

# Improve x-axis tick formatting for dates
fig.autofmt_xdate() # Auto-format date labels for better readability

# Add a legend - ensure unique labels are used for the legend
handles, labels = ax.get_legend_handles_labels()
# Create a dictionary to store unique handles and labels
unique_labels = dict(zip(labels, handles))

plt.legend(loc = 'upper left')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %%
#timeline in predicted test
plt.rcParams.update(plt.rcParamsDefault)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import dates as mdates # Import mdates for date formatting

# Map categorical labels to numerical values
y_pred_test_series = pd.Series(y_pred_test, index=y_test.index)
y_num = y_pred_test_series.map({'Normal': 0, 'Transitorio': 1, 'Falla': 2})

# Identify where the class changes
class_changes = y_num[y_num.diff() != 0]

# Create segments
segments = []
if not class_changes.empty:
    # First segment starts at the beginning of the series
    segments.append({'start': y_num.index[0], 'end': class_changes.index[0], 'class': y_num.iloc[0]})

    # Intermediate segments
    for i in range(len(class_changes) - 1):
        segments.append({
            'start': class_changes.index[i],
            'end': class_changes.index[i+1],
            'class': class_changes.iloc[i]
        })

    # Last segment starts at the last change point and ends at the end of the series
    segments.append({'start': class_changes.index[-1], 'end': y_num.index[-1], 'class': class_changes.iloc[-1]})
else:
    # If no class changes, the whole series is one segment
    if not y_num.empty:
        segments.append({'start': y_num.index[0], 'end': y_num.index[-1], 'class': y_num.iloc[0]})


fig, ax = plt.subplots(figsize=(12, 2)) # Adjust figure size as needed

# Define y-axis positions and colors for each class
y_positions = {0: 0, 1: 1, 2: 2}
class_colors = {0: 'green', 1: 'orange', 2: 'blue'} # Define colors for clarity
class_labels = {0: 'Normal', 1: 'Transitorio', 2: 'Falla'} # Define labels for legend

# Plot horizontal lines for each segment
for segment in segments:
    start_time = segment['start']
    end_time = segment['end']
    class_value = segment['class']
    y_pos = y_positions[class_value]
    color = class_colors[class_value]
    label = class_labels[class_value]

    # Plot a horizontal line for the segment
    ax.hlines(y_pos, start_time, end_time, color=color, lw=10) #lw line widht

first_transitorio_test = y_test[y_test == 'Transitorio'].index[0]
first_falla_test = y_test[y_test == 'Falla'].index[0]
ax.axvline(x=first_transitorio_test, color='red', linestyle='--', linewidth=1, label = 'Primer Transitorio real')

ax.axvline(x=first_falla_test, color='red', linestyle='dotted', linewidth=1, label = 'Primera Falla real')
ax.xaxis.set_major_locator(plt.MaxNLocator(5))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m %H:%M'))
#ax.set_xticklabels(ticklabels, fontsize=8);

#ax.set_ylabel("Class")
ax.set_title("Clase predicha - KNN_smoothing")

# Set y-axis ticks and labels
ax.set_yticks([y_positions[0], y_positions[1], y_positions[2]])
ax.set_yticklabels(["Normal", "Transitorio", "Falla"])
ax.set_ylim(-0.5,2.5)

# Improve x-axis tick formatting for dates
fig.autofmt_xdate() # Auto-format date labels for better readability

# Add a legend - ensure unique labels are used for the legend
handles, labels = ax.get_legend_handles_labels()
# Create a dictionary to store unique handles and labels
unique_labels = dict(zip(labels, handles))

plt.legend(loc = 'upper left')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %%
#Matriz de confusion con train
import seaborn as sns
import matplotlib.pyplot as plt

y_true = y_train
y_pred = y_pred_train
cm = confusion_matrix(y_true, y_pred, labels=["Normal", "Transitorio", "Falla"])

# heatmap
plt.figure(figsize=(4, 3)) # Optional: Adjust figure size
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Normal', 'Transitorio', 'Falla'],
            yticklabels=['Normal', 'Transitorio', 'Falla'])
plt.xlabel('Predicted Label', fontsize = 8)
plt.ylabel('True Label', fontsize = 8)
plt.title('Matriz de confusión en train', fontsize = 10)
plt.show()

# %%
#Matriz de confusion con test
import seaborn as sns
import matplotlib.pyplot as plt

y_true = y_test
y_pred = y_pred_test
cm = confusion_matrix(y_true, y_pred, labels=["Normal", "Transitorio", "Falla"])

# heatmap
plt.figure(figsize=(4, 3)) # Optional: Adjust figure size
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Normal', 'Transitorio', 'Falla'],
            yticklabels=['Normal', 'Transitorio', 'Falla'])
plt.xlabel('Predicted Label', fontsize = 8)
plt.ylabel('True Label', fontsize = 8)
plt.title('Matriz de confusión en test', fontsize = 10)
plt.show()

# %%
#FIRST TRANSITORIO REAL (iN test)
mask = (y_test == "Transitorio")
#y_test_series = pd.Series(y_test, index=y_test.index)
first_transitorio_test = (y_test[mask].first_valid_index())
print(first_transitorio_test)
#first_transitorio_test = y_test[y_test == 'Transitorio'].index[0]
# Out:
# 2015-06-14 18:33:10

# %%
#FIRST TRANSITORIO PREDICHO (test_pred)
mask2 = (y_pred_test == "Transitorio")
# Convert y_pred_train to a pandas Series with the same index as y_train
y_pred_test_series = pd.Series(y_pred_test, index=y_test.index)
print(y_pred_test_series[mask2].first_valid_index())
# Out:
# 2015-06-14 18:59:00

# %%
#FIRST TRUE TRANSITORIO PREDICHO (PARA TEST)
mask = (y_pred_test_series == 'Transitorio') & (y_test== 'Transitorio')
first_true_pred_transitorio_test = y_pred_test_series[mask].first_valid_index()
print(first_true_pred_transitorio_test)
# Out:
# 2015-06-14 18:59:00
